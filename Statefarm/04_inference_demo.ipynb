# %%
import os

for fname in ["driver_distraction_model.keras", "class_indices.json"]:
    if not os.path.exists(fname):
        print(f"Missing required file: {fname}. Please export/supply it before inferring.")
    else:
        print(f"Found {fname}")
# Out:
# Found driver_distraction_model.keras
# Found class_indices.json

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
import json

# Load the trained model
model = tf.keras.models.load_model('driver_distraction_model.keras')

# Load class mapping
with open('class_indices.json', 'r') as f:
    class_indices = json.load(f)
idx_to_class = {v: k for k, v in class_indices.items()}

def predict_image(img_path):
    img = image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img) / 255.0
    x = np.expand_dims(x, axis=0)
    pred = np.argmax(model.predict(x), axis=1)[0]
    return idx_to_class[pred]

# %%
print(os.listdir('../state-farm-distracted-driver-detection/imgs/train/c1')[:5])
# Out:
# ['img_100021.jpg', 'img_100045.jpg', 'img_100046.jpg', 'img_10011.jpg', 'img_100126.jpg']

# %%
# Prediction example
img_path = '../state-farm-distracted-driver-detection/imgs/train/c4/img_902.jpg' 
print("Predicted class:", predict_image(img_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Predicted class: c4
